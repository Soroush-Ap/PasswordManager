# %%
import os
import sys
import requests
import re
from bs4 import BeautifulSoup

# %%
# function to get the html source text of the medium article
def get_page():
    global url

    url = input("Enter url of a medium article: ")

    # handling possible error
    if not re.match(r'https?://medium.com/', url):
        print('Please enter a valid website, or make sure it is a medium article')
        sys.exit(1)

    res = requests.get(url)

    res.raise_for_status()
    soup = BeautifulSoup(res.text, 'html.parser')
    return soup

# %%
# function to remove all the html tags and replace some with specific strings
def clean(text):
    rep = {"<br>": "\n", "<br/>": "\n", "<li>":  "\n"}
    rep = dict((re.escape(k), v) for k, v in rep.items())
    pattern = re.compile("|".join(rep.keys()))
    text = pattern.sub(lambda m: rep[re.escape(m.group(0))], text)
    text = re.sub(r'\<(.*?)\>', '', text)
    return text

# %%
def collect_text(soup):
    text = f'url: {url}\n\n'
    para_text = soup.find_all('p')
    print(f"paragraphs text = \n {para_text}")
    for para in para_text:
        text += f"{para.text}\n\n"
    return text

# %%
# function to save file in the current directory
def save_file(text):
    if not os.path.exists('./scraped_articles'):
        os.mkdir('./scraped_articles')
    name = url.split("/")[-1]
    print(name)
    fname = f'scraped_articles/{name}.txt'

    with open(fname, 'w', encoding='utf-8') as f:
        f.write(text)

    print(f'File saved in directory {fname}')

# %%
# Run the pipeline: prompts for a URL, scrapes it, and saves the text
text = collect_text(get_page())
save_file(text)
# Out:
# Enter url of a medium article:  https://medium.com/@chukwudumebiii/ai-ml-dl-agi-what-they-mean-and-why-they-matter-a1f02b3f28be
# paragraphs text =
#  [<p class="z b an ao ap aq ar as at au av aw w"><span data-dd-action-name="Susi presentation tracker global_nav"><button class="z b an ao ax ap aq ay ar as az ba au bb bc aw bd be bf bg bh bi bj bk bl bm bn bo bp bq br bs bt bu bv" data-testid="headerSignUpButton">Sign up</button></span></p>, <p class="z b an ao ap aq ar as at au av aw w"><span data-dd-action-name="Susi presentation tracker global_nav"><a class="bx x by bz ca ab cb ac ae af ag ah ai aj ak" data-discover="true" data-testid="headerSignInButton" href="/m/signin?operation=login&amp;redirect=https%3A%2F%2Fmedium.com%2F%40chukwudumebiii%2Fai-ml-dl-agi-what-they-mean-and-why-they-matter-a1f02b3f28be&amp;source=post_page---top_nav_layout_nav-----------------------global_nav--------------------" rel="noopener follow">Sign in</a></span></p>, <p class="z b an ao ap aq ar as at au av aw w"><span data-dd-action-name="Susi presentation tracker global_nav"><button class="z b an ao ax ap aq ay ar as az ba au bb bc aw bd be bf bg bh bi bj bk bl bm bn bo bp bq br bs bt bu bv" data-testid="headerSignUpButton">Sign up</button></span></p>, <p class="z b an ao ap aq ar as at au av aw w"><span data-dd-action-name="Susi presentation tracker global_nav"><a class="bx x by bz ca ab cb ac ae af ag ah ai aj ak" data-discover="true" data-testid="headerSignInButton" href="/m/signin?operation=login&amp;redirect=https%3A%2F%2Fmedium.com%2F%40chukwudumebiii%2Fai-ml-dl-agi-what-they-mean-and-why-they-matter-a1f02b3f28be&amp;source=post_page---top_nav_layout_nav-----------------------global_nav--------------------" rel="noopener follow">Sign in</a></span></p>, <p class="z b y u w"><span class="lz">--</span></p>, <p class="z b cr u w">Listen</p>, <p class="z b cr u w">Share</p>, <p class="pw-post-body-paragraph nv nw id nx b ny nz oa ob oc od oe of og oh oi oj ok ol om on oo op oq or os hw cv" id="9229">Have you ever asked Siri a question and thought, <em class="ot">“How did my phone just know that?”</em> Or maybe you’ve played around with ChatGPT and wondered, <em class="ot">“Wait… is this thing a robot or what?”</em></p>, <p class="pw-post-body-paragraph nv nw id nx b ny nz oa ob oc od oe of og oh oi oj ok ol om on oo op oq or os hw cv" id="3582">From Netflix recommending movies, to cars that can drive themselves, to voice assistants that understand you better than some humans — artificial intelligence is all around us. Yet, most people still mix up the terms: <strong class="nx ie">AI, ML, DL, and AGI.</strong></p>, <p class="pw-post-body-paragraph nv nw id nx b ny nz oa ob oc od oe of og oh oi oj ok ol om on oo op oq or os hw cv" id="d888">Some will tell you they’re all the same. Others will smile and nod like they get it. But today, that ends.</p>, <p class="nv nw ot nx b ny nz oa ob oc od oe of og oh oi oj ok ol om on oo op oq or os hw cv" id="3b13"><strong class="nx ie"><em class="id">By the end of this article, you’ll be able to explain the difference between AI, ML, DL, and AGI — clearly, confidently, and even in your sleep.</em></strong></p>, <p class="pw-post-body-paragraph nv nw id nx b ny nz oa ob oc od oe of og oh oi oj ok ol om on oo op oq or os hw cv" id="75dd">Let’s break it down together — no jargon overload, just clear thinking and everyday examples.</p>, <p class="pw-post-body-paragraph nv nw id nx b ny pv oa ob oc pw oe of og px oi oj ok py om on oo pz oq or os hw cv" id="48f3">Artificial Intelligence, or AI, simply means giving machines the ability to <strong class="nx ie">think and act smart</strong> — like a human would.</p>, <p class="pw-post-body-paragraph nv nw id nx b ny nz oa ob oc od oe of og oh oi oj ok ol om on oo op oq or os hw cv" id="81d1">It is when a system, computer or device can do things like:</p>, <p class="pw-post-body-paragraph nv nw id nx b ny nz oa ob oc od oe of og oh oi oj ok ol om on oo op oq or os hw cv" id="36c1">In short, <strong class="nx ie">AI allows machines to perform tasks that would normally require human intelligence</strong> — such as re ...
# ai-ml-dl-agi-what-they-mean-and-why-they-matter-a1f02b3f28be
# File saved in directory scraped_articles/ai-ml-dl-agi-what-they-mean-and-why-they-matter-a1f02b3f28be.txt
